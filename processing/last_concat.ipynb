# %%
import pandas as pd

# %%
df_case1 = pd.read_csv('../resources/processed/v6/train_20241104_case1_economyup.csv')
df_case21 = pd.read_csv('../resources/processed/v6/filtered_second_cleanlab_ids_outlier.csv')
df_case22 = pd.read_csv('../resources/processed/v6/filtered_third_cleanlab_ids_outlier.csv')

# %%
df_case1 = df_case1.drop(['source', 'token_len'], axis=1)

# %%
df_case21
# Out:
#                         ID                                   text  target  \
# 0      ynat-v1_train_00727                       봄맞이 벚꽃 와인으로 취향저격       0
# 1      ynat-v1_train_00128         강원도 교원협회 교원들과 일점탈락제 도입에 대한 반대.       3
# 2      ynat-v1_train_01720          페이스북 메신저 암호화 기능 저커버그 미래는 프라이빗       4
# 3      ynat-v1_train_01947   미래에셋대우, 엔씨소프트 매출 1위 확보...매출 목표 상향 조정       5
# 4      ynat-v1_train_01562       김동연 부총리, 교육계와의 토론회서 혁신적 교육 정책 논의       3
# ...                    ...                                    ...     ...
# 10635  ynat-v1_train_00158                       최고 원중 의원 에 하는 교안       2
# 10636  ynat-v1_train_02025   박 대통령은 북핵 문제 해결을 위한 외교적 노력을 강조하고 있다.       2
# 10637  ynat-v1_train_00954             류현진, 콜로라도 맞이 전 다시 불펜 타격 연습       1
# 10638  ynat-v1_train_01835                   최정윤 전통춤 경연대회 대통령상 수상       0
# 10639  ynat-v1_train_02618  학교폭력에 대한 처벌을 요구하는 학생들과 정부의 대응에 대한 관심.       3
#
#       target_name  similarity
# 0            생활문화     0.20313
# ...

# %%
df_f1 = pd.concat([df_case1, df_case21])

# %%
df_f1['text'] = [x.strip() for x in df_f1['text']]

# %%
df_f1
# Out:
#                         ID                                   text  target  \
# 0      ynat-v1_train_00000  정부, '주파수 미사용' KT에 이용기간 2년 단축 처분(종합2보)       4
# 1      ynat-v1_train_00000              정부, KT 주파수 미사용에 강력한 제재 조치       4
# 2      ynat-v1_train_00000            KT, 주파수 미사용으로 이용기간 2년 단축 처분       4
# 3      ynat-v1_train_00000         KT, 주파수 미사용으로 인한 사용 기간의 2년 단축.       4
# 4      ynat-v1_train_00000         미사용 주파수에 대한 정부와 KT에 대한 강력한 제재.       4
# ...                    ...                                    ...     ...
# 10635  ynat-v1_train_00158                       최고 원중 의원 에 하는 교안       2
# 10636  ynat-v1_train_02025   박 대통령은 북핵 문제 해결을 위한 외교적 노력을 강조하고 있다.       2
# 10637  ynat-v1_train_00954             류현진, 콜로라도 맞이 전 다시 불펜 타격 연습       1
# 10638  ynat-v1_train_01835                   최정윤 전통춤 경연대회 대통령상 수상       0
# 10639  ynat-v1_train_02618  학교폭력에 대한 처벌을 요구하는 학생들과 정부의 대응에 대한 관심.       3
#
#       target_name  similarity
# 0            IT과학     0.20599
# ...

# %%
df_f1 = df_f1.drop_duplicates('text')

# %%
df_f1.to_csv('train_20241107_1.csv', encoding='utf-8-sig', index=0)

# %%
df_f2 = pd.concat([df_case1, df_case22])

# %%
df_f2['text'] = [x.strip() for x in df_f2['text']]

# %%
df_f2 = df_f2.drop_duplicates('text')

# %%
df_f2.to_csv('train_20241107_2.csv', encoding='utf-8-sig', index=0)
