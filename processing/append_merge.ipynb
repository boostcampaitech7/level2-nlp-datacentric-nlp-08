# %%
import pandas as pd
import numpy as np

# %%
df_ner = pd.read_csv('../resources/processed/v5/train_20241104_filtering_ner.csv')
df_gemma = pd.read_csv('../resources/processed/v5/train_20241104_filtering_gemma2.csv')

# %%
df_ner
# Out:
#        before_index                   ID  \
# 0                 0  ynat-v1_train_00000
# 1                 1  ynat-v1_train_00000
# 2                 2  ynat-v1_train_00000
# 3                 4  ynat-v1_train_00000
# 4                 5  ynat-v1_train_00000
# ...             ...                  ...
# 10151         14012                 2398
# 10152         14013                 2399
# 10153         14014                 2400
# 10154         14016                 2402
# 10155         14017                 2403
#
#                                                     text  target target_name  \
# 0                  정부, '주파수 미사용' KT에 이용기간 2년 단축 처분(종합2보)       4        IT과학
# 1                              정부, KT 주파수 미사용에 강력한 제재 조치       4        IT과학
# 2                            KT, 주파수 미사용으로 이용기간 2년 단축 처분       4        IT과학
# 3                         KT, 주파수 미사용으로 인한 사용 기간의 2년 단축.       4        IT과학
# 4                         미사용 주파수에 대한 정부와 KT에 대한 강력한 제재.       4        IT과학
# ...

# %%
df_ner
# Out:
#        before_index                   ID  \
# 0                 0  ynat-v1_train_00000
# 1                 1  ynat-v1_train_00000
# 2                 2  ynat-v1_train_00000
# 3                 4  ynat-v1_train_00000
# 4                 5  ynat-v1_train_00000
# ...             ...                  ...
# 10151         14012                 2398
# 10152         14013                 2399
# 10153         14014                 2400
# 10154         14016                 2402
# 10155         14017                 2403
#
#                                                     text  target target_name  \
# 0                  정부, '주파수 미사용' KT에 이용기간 2년 단축 처분(종합2보)       4        IT과학
# 1                              정부, KT 주파수 미사용에 강력한 제재 조치       4        IT과학
# 2                            KT, 주파수 미사용으로 이용기간 2년 단축 처분       4        IT과학
# 3                         KT, 주파수 미사용으로 인한 사용 기간의 2년 단축.       4        IT과학
# 4                         미사용 주파수에 대한 정부와 KT에 대한 강력한 제재.       4        IT과학
# ...

# %%
df_gemma_only = df_gemma[df_gemma['source'] == 'gemma2']

# %%
df_f = pd.concat([df_ner, df_gemma_only])

# %%
df_f.to_csv('train_20241104_filtering_ner_gemma2.csv', encoding='utf-8-sig', index=0)
