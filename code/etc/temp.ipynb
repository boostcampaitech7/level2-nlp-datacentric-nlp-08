# %%
import pandas as pd

# %%
source_df=pd.read_csv("resources/pre_processed_data/train_20241104.csv")

# %%
source_df
# Out:
#                         ID                                               text  \
# 0      ynat-v1_train_00000              정부, '주파수 미사용' KT에 이용기간 2년 단축 처분(종합2보)
# 1      ynat-v1_train_00000                          정부, KT 주파수 미사용에 강력한 제재 조치
# 2      ynat-v1_train_00000                        KT, 주파수 미사용으로 이용기간 2년 단축 처분
# 3      ynat-v1_train_00000                              정 파 미사 KT 이용기간 단 분종 보
# 4      ynat-v1_train_00000                     KT, 주파수 미사용으로 인한 사용 기간의 2년 단축.
# ...                    ...                                                ...
# 11609  ynat-v1_train_02797  C 버전을 업데이트한 후 텔레그램과 같은 메신저가 2시간 동안 다운되었는데 원인은 ...
# 11610  ynat-v1_train_02797  텔레그램 및 기타 암호화 메신저는 아시아에서 2시간 동안 다운되었습니다... 사용자 혼란
# 11611  ynat-v1_train_02797              C버전 업데이트 후 텔레그램 등 메신저 2시간 장애 발생, 원인은?
# 11612  ynat-v1_train_02798                    인터뷰 류현진 친구에게 안타 맞는 것 싫어해 승부는 냉정
# 11613  ynat-v1_train_02799                               지능정보사회 대비 국가 종합대책 마련
#
# ...

# %%
only_not_noisy_df=source_df[source_df['source']=='not_noisy']

# %%
only_not_noisy_df
# Out:
#                         ID                             text  target  \
# 21     ynat-v1_train_00003       갤노트 주말 만대 개통 시장은 불법 보조금 얼룩       4
# 29     ynat-v1_train_00005     美성인 명 중 명꼴 배우자 연인 빚 떠안은 적 있다       6
# 37     ynat-v1_train_00007         아가메즈 득점 우리카드 손해보험 완파 위 굳       1
# 38     ynat-v1_train_00008   朴대통령 얼마나 많이 놀라셨어요 경주 지진현장 방문종합       2
# 39     ynat-v1_train_00009       듀얼심 아이폰 하반기 출시설 솔솔 알뜰폰 기대감       4
# ...                    ...                              ...     ...
# 11602  ynat-v1_train_02794         문 대통령 김기식 금감원장 사표 수리키로종합       2
# 11603  ynat-v1_train_02795    트럼프 폭스뉴스 앵커들 충성도 점수매겨 점만점에 점도       6
# 11604  ynat-v1_train_02796        삼성 갤럭시 정식 출시 첫 주말 이통시장 잠잠       4
# 11612  ynat-v1_train_02798  인터뷰 류현진 친구에게 안타 맞는 것 싫어해 승부는 냉정       1
# 11613  ynat-v1_train_02799             지능정보사회 대비 국가 종합대책 마련       3
#
#       target_name     source
# 21           IT과학  not_noisy
# 29             세계  not_noisy
# 37            스포츠  not_noisy
# 38             정치  not_noisy
# ...

# %%
only_not_noisy_df.to_csv("resources/pre_processed_data/train_20241104_not_noisy_only.csv",encoding='utf-8-sig',index=False)
